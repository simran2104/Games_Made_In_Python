# %% [markdown]
# # Tic Tac Toe Game

# %% [markdown]
# ### Here is the series in which you both player1 and player2 to enter 'O' or 'X' respectively.
# ### You both have to enter the position of row and column of that place at which you want to add your sign.

# %% [markdown]
# ### Import Library

# %%
import numpy

# %% [markdown]
# ### Functions Definition

# %%
def check_rows(symbol):
    for r in range(3):
        count=0
        for c in range(3):
            if board[r][c]==symbol:
                count=count+1
        if count==3:
            print(symbol," won")
            return True
                
def check_cols(symbol):
    for r in range(3):
        count=0
        for c in range(3):
            if board[r][c]==symbol:
                count=count+1
        if count==3:
            print(symbol," won")
            return True

def check_diagonals(symbol):
    for r in range(3):
        count=0
        for c in range(3):
            if board[r][c]==symbol:
                count=count+1
        if count==3:
            print(symbol," won")
            return True

def won(symbol):
    return check_rows(symbol) or check_cols(symbol) or check_diagonals(symbol)

def place(symbol):
    print(numpy.matrix(board))
    while(1):
        row=int(input("Enter row 1 or 2 or 3: "))
        col=int(input("Enter column 1 or 2 or 3: "))
        if row>0 and row<4 and col>0 and col<4 and board[row-1][col-1]=='*':
            break
        else:
            print("Invalid input. Please enter again")
        board[row-1][col-1]=symbol


def play():
    for turn in range(9):
        if turn%2==0:
            print(p1name,", Your turn.")
            place(p1s)
            if won(p1s):
                break
        else:
            print(p2name,", Your turn.")
            place(p2s)
            if won(p2s):
                break

        if not won(p1s) and not won(p2s):
            print("Match is drawn.")
            print("\n\n"+"**************"+"\n\n")

# %% [markdown]
# ### Layout of game

# %%
board=numpy.array([['*','*','*'],['*','*','*'],['*','*','*']])
print(board)
p1name=input("Player 1, Enter your name: ")
p2name=input("Player 2, Enter your name: ")
p1s='X'
p2s='O'
print("\nHere is the series in which you both player1 and player2 to enter 'O' or 'X' respectively.")
print("You both have to enter the position of row and column of that place at which you want to add your sign.\n")

play()
# Out:
# [['*' '*' '*']
#  ['*' '*' '*']
#  ['*' '*' '*']]
# Player 1, Enter your name: Simran
# Player 2, Enter your name: Aadi
#
# Here is the series in which you both player1 and player2 to enter 'O' or 'X' respectively.
# You both have to enter the position of row and column of that place at which you want to add your sign.
#
# Simran , Your turn.
# [['*' '*' '*']
#  ['*' '*' '*']
#  ['*' '*' '*']]
# Enter row 1 or 2 or 3: 1
# Enter column 1 or 2 or 3: 1
# Match is drawn.
#
#
# **************
#
#
# Aadi , Your turn.
# [['*' '*' '*']
#  ['*' '*' '*']
#  ['*' '*' '*']]
# Enter row 1 or 2 or 3: 2
# Enter column 1 or 2 or 3: 1
# Match is drawn.
#
#
# **************
#
#
# Simran , Your turn.
# [['*' '*' '*']
#  ['*' '*' '*']
#  ['*' '*' '*']]
# Enter row 1 or 2 or 3: 1
# Enter column 1 or 2 or 3: 2
# Match is drawn.
#
#
# **************
#
#
# Aadi , Your turn.
# [['*' '*' '*']
#  ['*' '*' '*']
#  ['*' '*' '*']]
# Enter row 1 or 2 or 3: 2
# Enter column 1 or 2 or 3: 2
# Match is drawn.
#
#
# ...
